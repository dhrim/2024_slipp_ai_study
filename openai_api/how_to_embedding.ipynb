# %% [markdown]
# # openai 라이브러리 설치

# %%
# %pip install openai[datalib]
# Out:
# Requirement already satisfied: openai[datalib] in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (1.13.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (2.6.4)
# Requirement already satisfied: sniffio in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (4.10.0)
# Requirement already satisfied: numpy>=1 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (1.26.4)
# Requirement already satisfied: pandas-stubs>=1.1.0.11 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (2.2.0.240218)
# Requirement already satisfied: pandas>=1.2.3 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from openai[datalib]) (2.2.1)
# Requirement already satisfied: idna>=2.8 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai[datalib]) (3.6)
# Requirement already satisfied: certifi in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai[datalib]) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai[datalib]) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai[datalib]) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pandas>=1.2.3->openai[datalib]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pandas>=1.2.3->openai[datalib]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pandas>=1.2.3->openai[datalib]) (2024.1)
# Requirement already satisfied: types-pytz>=2022.1.1 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pandas-stubs>=1.1.0.11->openai[datalib]) (2024.1.0.20240203)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai[datalib]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai[datalib]) (2.16.3)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.3->openai[datalib]) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # openai 사용 선언과 키 설정

# %%
from openai import OpenAI

API_KEY = "sk-..."
client = OpenAI(api_key=API_KEY)

# %% [markdown]
# # 임베딩 함수

# %%
def get_embedding(text):
    response = client.embeddings.create(
        model="text-embedding-ada-002",
        input=text,
        encoding_format="float"
    )
    return response.data[0].embedding

# %%
embedding = get_embedding("Your text goes here")
print(embedding)
print(len(embedding))
# Out:
# [-0.013035916, -0.013468892, 0.009552122, -0.021595525, -0.025019366, 0.043963745, -0.019690428, -0.015773658, -0.010764456, -0.023300784, 0.0053555835, 0.016599644, -0.009865197, -0.0009741966, 0.0031074374, -0.0064413548, 0.024379894, -0.004003365, 0.014468068, -0.012229914, -0.004576226, 0.013302363, 0.013215768, 0.012249897, -0.004729433, 0.0010408083, 0.011856888, -0.017239116, 0.015986815, 0.009512155, 0.0059184525, -0.006298139, -0.02021, -0.006880992, -0.017811978, -0.009099163, 0.0024962747, -0.01589356, 0.02787035, -0.005182393, 0.011370623, 0.007733622, -0.0015911878, -0.0035870417, -0.0064413548, -0.023354074, -0.0019966867, 0.014095043, 0.005671989, 0.0036236783, 0.013635422, 0.008979262, -0.025538938, -0.002855978, -0.0037668934, 0.0048326813, -0.024140092, 0.013575471, 0.0054022116, 0.0016386487, 0.0016611301, -0.010318157, -0.011150804, 0.0034771324, -0.011190771, -0.015307376, -0.013935175, -0.021582201, 0.019956876, 0.012409766, 0.029096005, 0.016279908, 0.0070142155, -0.008386417, 0.015533856, 0.025099302, -0.0014071729, 0.01260294, -0.009731974, 0.0014188299, 0.011550475, -0.03820849, 0.0063547594, 0.02713762, 0.013049238, -0.000818908, 0.0035737194, 0.026205055, -0.024433184, -0.033865403, -0.0075471094, 0.018531384, 0.0061749076, 0.021369044, -0.0075004813, 0.0074804975, -0.013988464, 0.016959347, 0.016812801, -0.028110152, 0.016533032, 0.02593861, -0.011337317, -0.009665363, -0.024379894, 0.014214944, 0.011876872, -0.018637963, 0.013761984, 0.005405542, -0.026764594, 0.02100934, -0.009745296, -0.019157534, -0.007813556, 0.010324819, 0.0035337524, -0.018957699, -0.014241588, -0.035783824, 0.008146615, 0.017851945, 0.03162725, -0.011796938, 0.023407362, 0.012776131, -0.013149156, -0.028003572, 0.009811908, -0.0018035127, 0.042711444, 0.024206704, 0.007760267, 0.010531315, -0.019543882, 0.018891087, -0.041698944, 0.0038568194, -0.017505564, -0.017385662, 0.00431311, 0.035064418, 0.003850158, -0.0005295633, 0.013841918, 0.012030079, -0.0024230017, -0.009525478, 0.015387311, -0.020423157, 0.005888477, -0.0004446333, 0.011530491, -0.025299136, -0.011803599, 0.021702103, -0.015320699, 0.0070475214, 0.009512155, -0.028589755, 0.0023280801, 0.005635353, 0.02362052, -0.005295633, 0.035384152, 0.051051233, 0.009332304, -0.00874612, -0.009525478, -0.011816922, -0.02026329, 0.030614752, -0.050518338, 0.004469647, -0.03197363, 0.01749224, 0.023287462, 0.008826055, -0.026524791, -0.023713777, -0.044843018, -0.0014970987, 0.008706153, 0.023487298, -0.0143082, -0.012809436, 0.009338965, -0.0014737846, 0.0071674227, 0.0035470747, 0.015587145, 0.033199288, 0.009005906, -0.007307307, -0.6965988, -0.008186582, 0.015640436, -0.017838622, 0.017811978, 0.043404207, 0.001925079, 0.013708695, -0.017918557, 0.017811978, -0.013801951, -0.0031773797, -0.005019194, 0.004309779, -0.009925148, -0.009778602, 0.0073872413, -0.015880236, -0.02299437, 0.008532963, 0.00993847, 0.020676281, 0.009438883, 0.009965115, 0.019010989, 0.0076936553, 0.005082475, -0.01935737, -0.013475553, 0.028749624, -0.028536467, 0.0060649985, -6.681989e-05, 0.014881061, 0.0627749, -0.0067877355, -0.006461338, -0.004163233, 0.0010990936, 0.012669551, -0.025112623, -0.029335808, 0.023420686, -0.008932633, 0.0031474044, -0.012955982, -0.000190572, -0.020862795, 0.0069809095, 0.016146684, -0.0025195887, -0.00074605143, 0.0062714946, 0.0018434797, -0.0045928787, 0.0041365884, 0.04881308, -0.015573823, 0.0036636454, 0.010291513, -0.010711167, 0.016759511, -0.032746326, -0.023473974, 0.00022835334, -1.0694305e-05, -0.018051779, 0.014681226, 0.006118288, -0.0036703064, 0.006374743, 0.010338141, -0.02565884, 0.0047061187, 0.0049758963, 0.009778602, 0.015760336, -0.010777778, -0.021435656, 0.01959717, 0.011936823, -0.0060616676, -0.020223321, -0.022248318, 0.029442387, -0.015826948, -0.019264113, 0.012083368, 0.009678685, 0.0126895355, 0.010637893, 0.0044596554, -0.009458866, -0.00862622, 0.0027061016, -0.0010965957, -0.0066611734, 0.023021014, -0.0015087557, -0.002406349 ...
# 1536
